# %%
import pyotp
from smartapi import SmartConnect

totp_token="DOI7PP4ZISYMTWDVF6JKATRNOM"
API_KEY="rikcGWOx"
API_SECREAT_KEY="ef664992-0e06-497a-85f9-f0c468c1cb18"
USERNAME="G92658"
PWD="qwerty123"


obj = SmartConnect(api_key=API_KEY)
data = obj.generateSession(USERNAME, PWD, pyotp.TOTP(totp_token).now())
refreshToken= data['data']['refreshToken']
jwtToken = data['data']['jwtToken']
feedToken=obj.getfeedToken()
jwtToken
# Out:
# 'Bearer eyJhbGciOiJIUzUxMiJ9.eyJ1c2VybmFtZSI6Ikc5MjY1OCIsInJvbGVzIjowLCJ1c2VydHlwZSI6IlVTRVIiLCJpYXQiOjE2NjY2Nzk0MTMsImV4cCI6MTc1MzA3OTQxM30.3fiNwh_VYd0g4DAqbj4-vYtIQmJS6bEOevpDfT9jGrBhccO7kTctqHx5oTzPrAA1jIu-1zXgNfEeraPnSsAsuQ'

# %%
userProfile= obj.getProfile(refreshToken)
userProfile
# Out:
# {'status': True,
#  'message': 'SUCCESS',
#  'errorcode': '',
#  'data': {'clientcode': 'G92658',
#   'name': 'GAURAV TALELE',
#   'email': '',
#   'mobileno': '',
#   'exchanges': ['bse_cm', 'cde_fo', 'nse_cm', 'nse_fo', 'mcx_fo', 'ncx_fo'],
#   'products': ['BO', 'NRML', 'CO', 'CNC', 'MIS', 'MARGIN'],
#   'lastlogintime': '',
#   'broker': ''}}

# %%
from smartapi import SmartWebSocket
import pandas as pd
import json 


FEED_TOKEN=feedToken
CLIENT_CODE=USERNAME

token = "nse_fo|57217"
# token = "nse_fo|59306"

# token="mcx_fo|224395"
# token="nse_cm|2885&nse_cm|1594&nse_cm|11536&nse_cm|3045"
# token="mcx_fo|226745&mcx_fo|220822&mcx_fo|227182&mcx_fo|221599"
task="mw"   # mw|sfi|dp

ss = SmartWebSocket(FEED_TOKEN, CLIENT_CODE)

def on_message(ws, message):
    # print(message)
    s1 = json.dumps(message)
    d2 = json.loads(s1)
    # print("JSON Tick: {}".format(d2))
    # and (d2[0].get('task') != 'hb') and (d2[0].get('task') != 'cn')
    if(d2[0]['name'] !='hb' and d2[0]['name'] !='tm'):
        if(d2[0].get('task') == 'hb'):
            print("======================")
        else:
            print("===================================")
            print(d2[0])
            print("===================================")
    
def on_open(ws):
    print("on open")
    ss.subscribe(task,token)
    
def on_error(ws, error):
    print(error)
    
def on_close(ws):
    print("Close")

# Assign the callbacks.
ss._on_open = on_open
ss._on_message = on_message
ss._on_error = on_error
ss._on_close = on_close

ss.connect()

# DMI - 
# EMA 5,13,26 50, 200
# Stoc  -> below 40 -> Sell 
#       -> above 60 -> Buy
#
# Out:
# __on_open################
# {'task': 'cn', 'channel': 'NONLM', 'token': '094137857', 'user': 'G92658', 'acctid': 'G92658'}
# 2022-10-25 12:00:23.714956 : Start task in the background
# {'task': 'hb', 'channel': '', 'token': '094137857', 'user': 'G92658', 'acctid': 'G92658'}
# on open
# Error info: 'name'
# 'name'
# Error info: 'name'
# 'name'
# ===================================
# {'ap': '125.92', 'bp': '93.15', 'bq': '625', 'bs': '125', 'c': '182.85', 'cng': '-89.75', 'e': 'nse_fo', 'lo': '83.45', 'ltp': '93.10', 'ltq': '50', 'ltt': '25/10/2022 12:00:24', 'name': 'sf', 'nc': '-49.0839', 'sp': '93.40', 'tbq': '421775', 'tk': '57217', 'to': '5537083308.00', 'tsq': '696100', 'v': '43973025'}
# ===================================
# ===================================
# {'e': 'nse_fo', 'ltp': '93.65', 'ltq': '50', 'ltt': 'NA', 'name': 'sf', 'tk': '57217'}
# ===================================
# ===================================
# {'ap': '125.92', 'bp': '93.30', 'bq': '75', 'bs': '100', 'c': '182.85', 'cng': '-89.25', 'e': 'nse_fo', 'lo': '83.45', 'ltp': '93
 'ltq': '25', 'ltt': 'NA', 'name': 'sf', 'tk': '57217'}
# ===================================
# ===================================
# {'e': 'nse_fo', 'ltp': '94.65', 'ltq': '25', 'ltt': 'NA', 'name': 'sf', 'tk': '57217'}
# ===================================
# ===================================
# {'ap': '125.88', 'bp': '94.50', 'bq': '1000', 'bs': '125', 'c': '182.85', 'cng': '-88.20', 'e': 'nse_fo', 'lo': '83.45', 'ltp': '94.65', 'ltq': '25', 'ltt': '25/10/2022 12:00:46', 'name': 'sf', 'nc': '-48.2363', 'sp': '94.70', 'tbq': '421000', 'tk': '57217', 'to': '5541586917.00', 'tsq': '696575', 'v': '44022775'}
# ===================================
# Error info:
#
# Error info: SmartWebSocket.__on_close() takes 2 positional arguments but 4 were given
# SmartWebSocket.__on_close() takes 2 positional arguments but 4 were given

# %%
import pandas as pd
import pandas_datareader.data as web
import numpy as np

FB = web.YahooOptions('NIFTY.NS')

#showing available expiries
for exp in FB.expiry_dates:
     print(exp.isoformat())

# get call data
calls = FB.get_call_data()
calls

#get put data
puts  = FB.get_put_data()
puts


#get call data based on specific expiry
FB.get_call_data(month =2 , year = 2021)

# getting all call data, can also pass in a datetime to the expiry below
allcalls = FB.get_call_data(expiry= FB.expiry_dates)

#notice index is in multiindex
allcalls.index

#changing to regular index
allcalls.reset_index(inplace=True)

#get all available data for puts and calls at every expiration
alloptions = FB.get_all_data()

alloptions.reset_index(inplace=True)

# perform calculate on the data.
alloptions['mid_price'] = (alloptions.Ask - alloptions.Bid) / 2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas_datareader\yahoo\options.py:666, in Options.expiry_dates(self)
#     665 try:
# --> 666     expiry_dates = self._expiry_dates
#     667 except AttributeError:
#
# AttributeError: 'Options' object has no attribute '_expiry_dates'
#
# During handling of the above exception, another exception occurred:
#
# RemoteDataError                           Traceback (most recent call last)
# c:\Users\tejal\My Drive\OptionChainAnalyser\angel-one-connect.ipynb Cell 4 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/tejal/My%20Drive/OptionChainAnalyser/angel-one-connect.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> FB = web.YahooOptions('NIFTY.NS')
#       <a href='vscode-notebook-cell:/c%3A/Users/tejal/My%20Drive/OptionChainAnalyser/angel-one-connect.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> #showing available expiries
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tejal/My%20Drive/OptionChainAnalyser/angel-one-connect.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> for exp in FB.expiry_dates:
#       <a href='vscode-notebook-cell:/c%3A/Users/tejal/My%20Drive/OptionChainAnalyser/angel-one-connect.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a>      print(exp.isoformat())
#      <a href='vscode-notebook-cell:/c%3A/Users/tejal/My%20Drive/OptionChainAnalyser/angel-one-connect.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a> # get call data
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas_datareader\yahoo\options.py:668, in Options.expiry_dates(self)
#     666     expiry_dates = self._expiry_dates
#     667 except AttributeError:
# --> 668     expiry_dates = self._get_expiry_dates()
#     669 return expiry_dates
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas_datareader\yahoo\options.py:681, in Options._get_expiry_dates(self)
#     672 """
#     673 Gets available expiry dates.
#     674
#    (...)
#     677 List of datetime.date objects
#     678 """
#     680 url = self._OPTIONS_BASE_URL.format(sym=self.symbol)
# --> 681 jd = self._parse_url(url)
#     683 expiry_dates = [
#     684     dt.datetime.utcfromtimestamp(ts).date()
#     685     for ts in jd["optionChain"]["result"][0]["expirationDates"]
#     686 ]
#     688 if len(expiry_dates) == 0:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas_datareader\yahoo\options.py:707, in Options._parse_url(self, url)
#     694 def _parse_url(self, url):
#     695     """
#     696
#     697     Downloads and parses a URL into a json object.
#    (...)
#     705     A JSON object
#     706     """
# --> 707     jd = json.loads(self._read_url_as_StringIO(url).read())
#     708     if jd is None:  # pragma: no cover
#     709         raise RemoteDataError(
#     710             "Parsed URL {0!r} is not " "a valid json object".format(url)
#     711         )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas_datareader\base.py:119, in _BaseReader._read_url_as_StringIO(self, url, params)
#     115 def _read_url_as_StringIO(self, url, params=None):
#     116     """
#     117     Open url (and retry)
#     118     """
# --> 119     response = self._get_response(url, params=params)
#     120     text = self._sanitize_response(response)
#     121     out = StringIO()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas_datareader\base.py:181, in _BaseReader._get_response(self, url, params, headers)
#     178 if last_response_text:
#     179     msg += "\nResponse Text:\n{0}".format(last_response_text)
# --> 181 raise RemoteDataError(msg)
#
# RemoteDataError: Unable to read URL: https://query1.finance.yahoo.com/v7/finance/options/NIFTY.NS
# Response Text:
# b'Forbidden'
