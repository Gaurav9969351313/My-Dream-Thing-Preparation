# %%
import requests
import pandas as pd
import numpy as np

date = "04102022"
daily_security_wise_dilivery_report_url = 'https://archives.nseindia.com/archives/equities/mto/MTO_'+date+'.DAT'
report_file = requests.get(daily_security_wise_dilivery_report_url)
path = './' + date + '.DAT'
open(path, 'wb').write(report_file.content)

topex = np.fromfile(path)
df_topex = pd.DataFrame(data=topex)
df_topex.head(10)
# Out:
#                0
# 0  1.130732e+277
# 1  6.524643e+179
# 2   9.538027e+77
# 3  1.815969e-152
# 4  2.886987e+214
# 5  2.108822e+214
# 6  4.885731e+252
# 7  2.657653e-258
# 8   1.222444e-76
# 9   8.518801e-96

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('./04102022.DAT', sep='|', header=0, skipinitialspace=True)
data.dropna(inplace=True)
df = data['Security Wise Delivery Position - Compulsory Rolling Settlement']

dff = pd.DataFrame([sub.split(",") for sub in df])

data_df = dff.iloc[2:]
data_df.drop(columns=[data_df.columns[0],data_df.columns[1]], axis=1, inplace=True)
data_df
# fig, ax =plt.subplots(figsize=(22,10))
# ax.axis('tight')
# ax.axis('off')

# the_table = ax.table(cellText=data_df.values,colLabels=data_df.columns,loc='left')
# fig

# inner join with NIFTY 500 thats it
# Out:
# C:\Users\tejal\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                      2                3  \
# 2     Name of Security  Quantity Traded
# 3            20MICRONS               EQ
# 4           21STCENMGM               EQ
# 5           364D030823               TB
# 6            3IINFOLTD               EQ
# ...                ...              ...
# 2120              ZOTA               EQ
# 2121             ZUARI               EQ
# 2122          ZUARIIND               EQ
# 2123         ZYDUSLIFE               EQ
# 2124         ZYDUSWELL               EQ
#
#                                                     4  \
# 2     Deliverable Quantity(gross across client level)
# ...

# %%
import pandas as pd


reference_df_200 = pd.read_csv('./page_directory/reference/NIFTY200.csv')
reference_df_200
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\tejal\My Drive\new-bx-ssd-notes\MY_TELEGRAM_SERVICES\NSE-daily-reports.ipynb Cell 3 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/tejal/My%20Drive/new-bx-ssd-notes/MY_TELEGRAM_SERVICES/NSE-daily-reports.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tejal/My%20Drive/new-bx-ssd-notes/MY_TELEGRAM_SERVICES/NSE-daily-reports.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> reference_df_200 = pd.read_csv('./page_directory/reference/NIFTY200.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/tejal/My%20Drive/new-bx-ssd-notes/MY_TELEGRAM_SERVICES/NSE-daily-reports.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> reference_df_200
#
# ...
